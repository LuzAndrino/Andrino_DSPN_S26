# %% [markdown]
# ### Final Project for CMU DSPN Spring 2026 | Luz Stephanie Andrino, PhD Candidate in Systems Neuroscience
#
#
#
# # *Assessing the efficacy of Envelope Following Responses (EFRS) in a model of cochlear neural degeneration (CND) across graded noise exposure*

# %% [markdown]
# # Background
# > Introduction:
#
#
# > **Hypothesis:**
#
#
# > Data acquisition:

# %% [markdown]
# ## Figure 1:
# <br>
#
# ![Table 1:](timeline.png)

# %% [markdown]
# ## Figure 2:
#
# <br>
#
# ![Table 1:](ribbon_synapses-kujawa-liberman2015.png)
# *(Kujawa & Liberman, 2015)*

# %%
#Figure 1: 
# image of NE timeline 

#Figure 2:
#image of synapses 


#Figure 3
# image of tmtf?

# %%
# Out:
# Error in parse(text = input): <text>:1:8: unexpected symbol
# 1: import numpy
#            ^
# Traceback:

# %%
#data prep (20pts)(Cleansing & architecture) 
#The data architecture is clearly defined.
#The data have been checked for anomalies.

# %% [markdown]
# ## Data Variables
# **Subject ID** (GERXX-XX) : The animal ID is denoted by GER for gerbil model, then the ID and year it was born.

# %%
#need to prep separate csvs for everything.. 
# list out what i need

# %% [markdown]
# ## Data Organization
#
# **Data Cleaning**
# 1. Check for NA's
# 2. Tukey outlier detection
#
#
# **Statistical Analyses & Techniques**
# 1.

# %%
#Visualization (20pts) (What was found? How can we see it?) 20
#Graphical integrity. Are plots clear and communicating results accurately & effectively?
#Visual balance: i.e., data:ink ratio & white space balance
#Simplicity-complexity balance: are plots as simple as possible & as complex as necessary?
#A clear understanding of visual/perceptual biases and optimal use of data visualizationn.

# %%
#Setup: Load libraries needed
library(ggplot2)
library(tidyverse)

# %% [markdown]
# # Analysis & Techniques
# > Based off of **Representational similarity analysis**
# #### Technique 1: Blah Blah
# > Q: Do EFRs have a high correlation to ?
# #### Technique 2:
# #### Technique 3:

# %%
#analysis thoughts
# RSA requires randomization and bootstrapping
#Tech1: Bootstrapping 
#tech 2: permutation testing?
#pairwise comparisons
#By using sub-dermal eeg we get high temporal resolution t
#calculate dissimilarity matrix - heatmap : a face is not a house~ how does this correlate for efrs

#stimulus presentation - visual uses gabor filters - what would be my version -- fig 7

# %% [markdown]
# # Visualizations for Technique 1:

# %% [markdown]
# # Conclusion for Technique 1:

# %% [markdown]
# #### Citations
# - Kujawa SG, Liberman MC. Synaptopathy in the noise-exposed and aging cochlea: Primary neural degeneration in acquired sensorineural hearing loss. Hear Res. 2015 Dec;330(Pt B):191-9. doi: 10.1016/j.heares.2015.02.009. Epub 2015 Mar 11. PMID: 25769437; PMCID: PMC4567542.
