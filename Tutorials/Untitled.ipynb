% %% [markdown]
% ## Correlation plot between EFR SL & 3k Synaptic count
%
% ### polypredsci

% %% [markdown]
% ### Creating dataframe - gerbil synapse come from histology sheet and aging_histology info

% %%
#Young 
freqs =    [0.5;          1;     3;            8;            16;           32          ];
GER13_21 = [26.30769231;  26.56; 28.69565217;  19.69230769;  22.84615385;  26.42857143];

% %%
freqs
